# %% [markdown]
# # 11_gene_expression_R_xclone

# %%
suppressPackageStartupMessages({
  library(ggplot2)
  library(dplyr)
  library(tidyverse)
  library(Matrix)
  library(Hmisc)
  library(reshape2)
  library(viridis)
  library(RColorBrewer)
  library(ggalluvial)
  library(gplots)
  library(grid)
  library(ggforce)
library(scales)
library(gridExtra)    
library(rlang)
})
# Out:
# Warning message:
# “package ‘ggplot2’ was built under R version 4.5.2”
# Warning message:
# “package ‘readr’ was built under R version 4.5.2”
# Warning message:
# “package ‘purrr’ was built under R version 4.5.2”
# Warning message:
# “package ‘stringr’ was built under R version 4.5.2”
# Warning message:
# “package ‘reshape2’ was built under R version 4.5.2”

# %%
options(tibble.width = Inf)
options(repr.matrix.max.cols = Inf)

# %% [markdown]
# ## plot parameters

# %%
FONT.SIZE <- 7
LABEL.FONT.SIZE <- 7
w <- 2 
h <- 2.5
LINE.W <- 0.5/2.141959

# Set geom defaults globally
update_geom_defaults("line",      list(linewidth = LINE.W))
update_geom_defaults("errorbar",  list(linewidth = LINE.W))
#update_geom_defaults("point",     list(size = LINE.W, stroke = LINE.W))

settheme <- theme_minimal() + 
  theme(
    text = element_text(family = "sans"), 
    panel.background = element_blank(),
    panel.grid.major = element_blank(), 
    panel.grid.minor = element_blank(),
    plot.background = element_blank(),
    axis.ticks = element_line(colour = "black", linewidth = LINE.W),
    axis.ticks.length = unit(0.1, "cm"), 
    axis.line = element_line(linewidth = LINE.W, colour = "black"),
    axis.title = element_text(size = FONT.SIZE),
    axis.text = element_text(colour = "black", size = FONT.SIZE),
    strip.text = element_text(size = FONT.SIZE), 
    strip.text.y.left = element_text(angle = 0, hjust = 1, size = FONT.SIZE),
    legend.position = "right",
    legend.title = element_text(size = FONT.SIZE), 
    legend.text = element_text(size = FONT.SIZE),
    legend.key.size = unit(0.3, "cm"),
    axis.text.x = element_text(colour = "black", angle = 0, size = LABEL.FONT.SIZE),
    title = element_text(size = FONT.SIZE) 
  )

# %%
custom_palette <- c(
  "#555e7b", "#b7d968", "#b576ad", "#e04644", "#fde47f", "#7ccce5", 
  "#C6E5D9", "#F0A830", "#e04644", "#C0D860", "#F2F26F", "#A8E6CE", 
  "#CCC68D", "#EB6841", "#E1F5C4", "#D9CEB2", "#C5CEAE", "#E84A5F", 
  "#A0C55F", "#DCE9BE", "#FFAAA6", "#F07818", "#E08E79", "#A0C55F", 
  "#948C75", "#C0D860", "#005F6B", "#45484B", "#0B2E59", "#FFF7BD", 
  "#CFBE27", "#F1D4AF", "#C02942", "#5E412F", "#355C7D", "#F27435", 
  "#AAB3AB", "#4ECDC4", "#8C2318", "#FF9E9D", "#E6AC27", "#C7F464", 
  "#4ECDC4", "#ED303C", "#F4FAD2", "#F07818", "#031634", "#838689", 
  "#73626E", "#F9D423", "#C06C84", "#F04155", "#F5634A", "#DFBA69", 
  "#A0C55F"
)

color_ploidy = c("diploid"= "white","normal"= "white", "monosomy"="#109E9D","trisomy"="#F26B3B","complex"= "#886DB0")
color_ploidy_2 = c("diploid"= adjustcolor("grey77", alpha = 0.5) ,"normal"= "white", "monosomy"="#109E9D","trisomy"="#F26B3B","complex"= "#886DB0")
color_ploidy_chr = c("normal"= "white","monosomy"="#109E9D","trisomy"="#F26B3B")

color_condition = c("Control" = "#7BBA56", 
               "Reversine" = "#87549B", 
               "Mix" = "#E8973E")

celltype_colors = c(
    "naive EPI"=    "#ecbb5f",  # warm yellow
        "EPI"=    "#ecbb5f",  # warm yellow
    "blastoid EPI"= "#f69320",  # orange
    "TE"=      "#4f5b9e",  # blue
    "unspecified"=       "#676868")

color_sample = c(
  # Control group colors
  "T1_control" = "#B5C649",
  "T2_control" = "#66BC52",
  "T3_control" = "#009791",
  # Reversine group colors
  "T1_rev" = "#B686BD",
  "T2_rev" = "#A263B2",
  "T3_naive_rev" = "#754383",
  "T3_rev" = "#4A314F",
  # Mix group colors
  "T2_mix" = "#FDCF5F",
  "T3_mix_good" = "#F29923",
  "T3_mix_bad" = "#945200"
)

color_celltype = c(
    "naive EPI" =     "#F8B949",  # warm yellow
    "blastoid EPI" = "#E8973E",  # orange
    "TE" =        "#4B5AA3",  # blue
    "unspecified" =        "#676767")

color_celltype2 = c(
    "EPI" =     "#E79033",  # warm yellow
    "TE" =        "#4B5AA3",  # blue
    "unspecified" =        "#676767")


levels_vec <- as.character(1:22)
col_monosomy <- viridis_pal(option = "mako")(22)
names(col_monosomy) <- rev(levels_vec)

levels_vec <- as.character(1:22)
col_trisomy <- viridis_pal(option = "rocket")(22)
names(col_trisomy) <- rev(levels_vec)

#c("normal"= "#E0E0E0","monosomy"="#109E9D","trisomy"="#F26B3B")

# %% [markdown]
# ## Directories and Files

# %%
outdir = "/nfs/team292/rs40/projects/Aneuploid_screen_v2/processed_data/11_geneexpression_xclone"
inputdir = "/nfs/team292/rs40/projects/Aneuploid_screen_v2/processed_data/11_geneexpression"

# %%
scploid_df = read_csv( "/nfs/team292/rs40/projects/Aneuploid_screen_v2/processed_data/7_2_xclone/cell_karyotype_scploid.csv")
# Out:
# New names:
# • `` -> `...1`
# Rows: 38655 Columns: 8
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (3): cell, karyotype, ploidy
# dbl (5): ...1, num_gain_chr, num_loss_chr, num_chr, num_abnormal_chr
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.

# %%
# 1. Load the pieces
# counts <- readMM(sprintf("%s/matrix.mtx",outdir))
# genes  <- read_csv("scanpy_export_for_R/genes.csv")$cell_symbol # Check col name in CSV
# meta   <- read_csv("scanpy_export_for_R/metadata.csv") %>% rename(barcode = 1)
# umap   <- read_csv("scanpy_export_for_R/umap_coords.csv") %>% rename(barcode = 1)
counts <- readMM(sprintf("%s/matrix_hvg.mtx",inputdir))
genes  <- read_csv(sprintf("%s/genes_hvg.csv",inputdir))$`0`
meta   <- read_csv(sprintf("%s/metadata.csv",inputdir))%>% rename(barcode = 1)
umap   <- read_csv(sprintf("%s/umap_coords.csv",inputdir))%>% rename(barcode = 1)
mlm_PROGENy_df  <- read_csv(sprintf("%s/progeny_mlm_scores.csv",inputdir ))
mlm_hallmark_df  <- read_csv(sprintf("%s/hallmark_mlm_scores.csv",inputdir ))
# Out:
# Rows: 33540 Columns: 1
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (1): 0
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# New names:
# • `` -> `...1`
# Rows: 38655 Columns: 37
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (13): dataset, cell.ID_, n_genes_group, phase, persample_celltype, sampl...
# dbl (23): ...1, scrublet_score, scrublet_cluster_score, scrublet_zscore, scr...
# lgl  (1): scrublet_prediction
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# New names:
# • `` -> `...1`
# Rows: 38655 Columns: 3
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# dbl (3): ...1, UMAP1, UMAP2
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# Rows: 38655 Columns: 15
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr  (1): cell
# dbl (14): Androgen, EGFR, Estrogen, Hypoxia, JAK-STAT, MAPK, NFkB, PI3K, TGF...
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# Rows: 38655 Columns: 51
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr  (1): cell
# dbl (50): ADIPOGENESIS, ALLOGRAFT_REJECTION, ANDROGEN_RESPONSE, ANGIOGENESIS...
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.

# %% [markdown]
# ## Reformat

# %%
rownames(counts) <- genes
colnames(counts) <- meta$barcode # or barcode col

# %%
meta <- meta %>% mutate(barcode = as.character(barcode))
umap <- umap %>% mutate(barcode = as.character(barcode))
plot_base <- meta %>% left_join(umap, by = "barcode")

# %%
# Combine
gene_exp <- as.matrix(t(counts))
gene_exp_df <- as_tibble(gene_exp, rownames = "barcode")
# Out:
# Warning message in asMethod(object):
# “sparse->dense coercion: allocating vector of size 9.7 GiB”

# %%
## Run this if not subsetting
# Join with our UMAP and Metadata
meta_genes_df= plot_base %>% left_join(gene_exp_df, by = "barcode")

# Combine with scpoid
meta_genes_df <- meta_genes_df %>% 
  mutate(cell.ID_ = as.character(cell.ID_))

scploid_df <- scploid_df %>% 
  mutate(cell = as.character(cell))

# 2. Join the dataframes
# We use 'c("target_col_in_left" = "target_col_in_right")'
combined_df <- meta_genes_df %>%
  left_join(scploid_df, by = c("cell.ID_" = "cell"))

# %%
apoptosis = c("AEN", "RPS27L", "GPX1", "EDA2R", "CDKN1A", "RRM2B", "BCL2L13")

stress_response = c("CALM3", "SESN1", "POLH", "DDB2", "PPM1D", "KCNK1", "MDM2", "PLK2", "CEP63",
                    "NUCKS1", "GTF2H5","ATP6V0A2", "PLEKHA1")

adhesion = c("CDH1", "TJP1",  #ZO1
             "ACTB", "ACTG1",  "ITGB1", "ITGA6", "ITGAV", "ITGB5",
            "NECTIN2", "F11R" ,#JAM1
             "CDH3", "EPCAM", "DSG2","GJA1",
            "OCLN", "PVR", "NECTIN1", "BCAM", "ICAM1", "ITGA9", "CLDN1", "ITGA2", "CXADR")

adhesion_sub = c("CDH1",  #E-CAD
               "ACTB", "ACTG1",  #F-actin components
                 "OCLN","CLDN1","TJP1","F11R",  #ZO1, tight junction related
                 "GJA1", #gap junction
                 "EPCAM") #Epithelial Cell Adhesion Molecule


non_intrisic_apoptosis = c("FASLG", "TNF", "TNFSF10" , "TRAIL", "FAS", "TNFRSF6", "TNFRSF1A", "TNFRSF10A", "TNFRSF10B")





adhesion_sub2 = c("CDH1", "OCLN","CLDN1","TJP1","F11R", "GJA1") #Epithelial Cell Adhesion Molecule




mlm_PROGENy_var = setdiff(colnames(mlm_PROGENy_df), "cell")

mlm_hallmark_var = c('APICAL_JUNCTION', 'APICAL_SURFACE', 'APOPTOSIS',
       'COMPLEMENT', 'DNA_REPAIR', 'E2F_TARGETS',
       'EPITHELIAL_MESENCHYMAL_TRANSITION', 'ESTROGEN_RESPONSE_EARLY',
       'ESTROGEN_RESPONSE_LATE', 'FATTY_ACID_METABOLISM', 'G2M_CHECKPOINT',
       'GLYCOLYSIS', 'HEDGEHOG_SIGNALING', 'HYPOXIA',
       'IL2_STAT5_SIGNALING', 'IL6_JAK_STAT3_SIGNALING',
       'INFLAMMATORY_RESPONSE', 'INTERFERON_ALPHA_RESPONSE',
       'INTERFERON_GAMMA_RESPONSE', 'KRAS_SIGNALING_DN', 'KRAS_SIGNALING_UP',
       'MITOTIC_SPINDLE', 'MTORC1_SIGNALING', 'MYC_TARGETS_V1',
       'MYC_TARGETS_V2', 'NOTCH_SIGNALING',
       'OXIDATIVE_PHOSPHORYLATION', 'P53_PATHWAY', 
       'PEROXISOME', 'PI3K_AKT_MTOR_SIGNALING', 'PROTEIN_SECRETION',
       'REACTIVE_OXYGEN_SPECIES_PATHWAY', 
       'TGF_BETA_SIGNALING', 'TNFA_SIGNALING_VIA_NFKB',
       'UNFOLDED_PROTEIN_RESPONSE', 'UV_RESPONSE_DN',
       'WNT_BETA_CATENIN_SIGNALING')

EMT_genes = c("CDH2","SNAI1", "SNAI2", "ZEB1", "ZEB2","TWIST", "VIM")

TE_genes = c( "GATA2", "GATA3", "CDX2", "TFAP2C", "KRT7", "KRT18", "OVOL1")

EPI_genes= c("POU5F1", "GDF3", "ARGFX", "NANOG", "SOX2", "KLF17", "TDGF1")

# %%
plot_genes <- unique(c(apoptosis, stress_response, adhesion, TE_genes,EPI_genes, EMT_genes, non_intrisic_apoptosis))

# %%
## Or subset genes to reduce size
get_gene_plot_data <- function(target_genes) {
    
  # rownames of counts are your valid gene IDs
  genes_in_counts <- rownames(counts)

  # keep only genes that exist
  keep <- intersect(target_genes, genes_in_counts)
  missing <- setdiff(target_genes, genes_in_counts)
  message(paste(head(missing, 20), collapse = ", "))

  # Extract expression for listed genes and convert to dense for the plot
  gene_exp <- as.matrix(t(counts[keep, , drop = FALSE]))
  gene_exp_df <- as_tibble(gene_exp, rownames = "barcode")
  # Join with our UMAP and Metadata
  plot_base %>% left_join(gene_exp_df, by = "barcode")
}

# 1) Start from plot_base + only the genes you need
meta_genes_df <- get_gene_plot_data(plot_genes)

# 2) Make sure the join key exists and is consistent
# If scploid_df uses "cell", create a matching "cell" column in meta_genes_df from barcode
meta_genes_df <- meta_genes_df %>%
  mutate(cell = as.character(barcode))

scploid_df <- scploid_df %>%
  mutate(cell = as.character(cell))

# 3) Join with scploid
combined_df_1 <- meta_genes_df %>%
  left_join(scploid_df, by = c("cell.ID_" =  "cell"))

# 4) Join with mlm_progeny
combined_df_2 <- combined_df_1 %>%
  left_join(mlm_PROGENy_df, by = c("cell.ID_" =  "cell"))

# 4) Join with mlm_hallmark
combined_df <- combined_df_2 %>%
  left_join(mlm_hallmark_df, by = c("cell.ID_" =  "cell"))
# Out:
# TWIST, TRAIL, TNFRSF6

# %%
 # Gene order (top-to-bottom = target_genes order reversed)
  ploidy_order = c("diploid", "trisomy", "monosomy", "complex")
  combined_df$ploidy <- factor(combined_df$ploidy, levels = ploidy_order)

# %%
head(combined_df )
# Out:
#   barcode dataset            cell.ID_
# 1 0       Embryo-Imp15265938 AAACCTGAGCGATCCC-1_Embryo-Imp15265938
# 2 3       Embryo-Imp15265938 AAACCTGCAATCACAC-1_Embryo-Imp15265938
# 3 5       Embryo-Imp15265938 AAACCTGCAGCTGCTG-1_Embryo-Imp15265938
# 4 6       Embryo-Imp15265938 AAACCTGCAGTGACAG-1_Embryo-Imp15265938
# 5 8       Embryo-Imp15265938 AAACCTGCATGTTGAC-1_Embryo-Imp15265938
# 6 9       Embryo-Imp15265938 AAACCTGGTAGCGTCC-1_Embryo-Imp15265938
#   scrublet_score scrublet_prediction scrublet_cluster_score scrublet_zscore
# 1 0.07129456     FALSE               0.08256881             -0.6249869
# 2 0.19064748     FALSE               0.19851577              0.5055552
# 3 0.22540984     FALSE               0.22540984              0.7677861
# 4 0.33522727     FALSE               0.21584158              0.6744908
# 5 0.20689655     FALSE               0.20689655              0.5872721
# 6 0.09309967     FALSE               0.08256881             -0.6249869
#   scrublet_bh_pval scrublet_bonf_pval n_genes_by_counts total_counts
# 1 1                0.9147751          4923              17150
# 2 1                0.8326981          8112              54075
# 3 1                0.8326981          8801              68329
# 4 1                0.8326981          7949              49264
# 5 1                0.8326981          7336              42984
# 6 1                0.9147751          7621              42425
#   total_counts_mt pct_counts_mt total_counts_ribo pct_counts_ribo n_genes_group
# 1  481            2.804665       4445             25.91837        low
# 2 1514            2.799815      13757             25.44059        high
# 3 1605            2.348929      17109             25.03915        high
# 4 1386            2.813413      12155             24.67319        high
# 5  860            2.000744      10845             25.23032        high
# 6 1402            3.304655      10427             24.57749        high
#   S_score      G2M_score   phase leiden mef_score  persample_celltype
# 1  0.291071261 -0.07524606 S     8       0.4381818 unknown
# 2 -0.046718237  0.36545115 G2M   0      -3.2758442 EPI
# 3 -0.044351377  0.21209913 G2M   0      -4.6309091 EPI
# 4 -0.009972636 -0.14632259 G1    0      -2.0374026 EPI
# 5 -0.003507561  0.16899508 G2M   0      -2.5353247 EPI
# 6  0.373325527  0.05538903 S     8       0.8384416 diff
#   sample_celltype sample     timepoint Condition State n_genes
# 1 low quality     T1_control day1      Control   Naïve 4923
# 2 EPI             T1_control day1      Control   Naïve 8112
# 3 EPI             T1_control day1      Control   Naïve 8801
# 4 EPI             T1_control day1      Control   Naïve 7949
# 5 EPI             T1_control day1      Control   Naïve 7336
# 6 TE              T1_control day1      Control   Naïve 7621
#   stress_score_vandenBrink leiden_theta0 leiden_theta1 leiden_theta2
# 1 0.3239384                11            2             1
# 2 0.2379417                 0            0             2
# 3 0.2474431                 0            0             3
# 4 0.3294210                 9            0             3
# 5 0.2769359                 0            0             2
# 6 0.3519634                 7            7             8
#   leiden_theta3 integrated_celltype leiden_lowres celltype_fine celltype_coarse
# 1 10            unspecified         7             unspecified_2 unspecified
# 2  4            naive EPI           1             EPI_1         EPI
# 3  1            naive EPI           1             EPI_1         EPI
# 4  1            naive EPI           1             EPI_1         EPI
#   SPERMATOGENESIS TGF_BETA_SIGNALING TNFA_SIGNALING_VIA_NFKB
# 1  0.84911871     4.410874           -0.9749687
# 2  0.06862968     5.039883           -2.0331295
# 3 -0.76163867     4.645857           -2.0344124
# 4  0.40430285     4.115032           -0.9995399
# 5 -0.53455662     3.867135           -0.9888665
# 6 -0.03126961     2.609610           -0.9323944
#   UNFOLDED_PROTEIN_RESPONSE UV_RESPONSE_DN UV_RESPONSE_UP
# 1  7.658166                 0.3950144      4.561288
# 2 11.711983                 0.7935481      1.280116
# 3 11.696341                 0.6422843      1.922998
# 4 13.146498                 1.4000839      1.910147
# 5 14.862468                 0.2503796      3.327780
# 6 10.111446                 1.8857148      3.901106
#   WNT_BETA_CATENIN_SIGNALING XENOBIOTIC_METABOLISM
# 1 -2.1297247                 -0.1550725
# 2 -1.2663679                  0.7281318
# 3 -1.7834092                  1.2398202
# 4 -0.9054740                  1.4938179
# 5 -1.6467131                  2.0888628
# 6  0.3318068                 -1.5930503

# %%
length(plot_genes )

missing <- setdiff(plot_genes , rownames(counts))
length(missing)
head(missing)
# Out:
# [1] 73
# [1] 3
# [1] "TWIST"   "TRAIL"   "TNFRSF6"

# %% [markdown]
# ## Cycling fraction

# %% [markdown]
# ## A_Dot plot

# %% [markdown]
# ### function

# %%
make_gene_dotplot <- function(combined_df,
                                             sample = "sample",
                                             target_genes,
                                             w = 4, h = 3,
                                             title = "Gene Expression vs others mean",
                                             expr_thresh = 0,
                                             endcolor = "#3F8F91",
                                             alpha = 0.05,
                                             highlight_direction =  "up",
                                             delta_min = 0.1,              # effect-size gate (highly recommended)
                                             highlight_color = "black",
                                             highlight_stroke = 0.3,
                                             p_adjust_method = "BH") {

  highlight_direction <- match.arg(highlight_direction)

  df_sub <- combined_df %>%
    select(all_of(sample), any_of(target_genes))

  present_genes <- intersect(target_genes, colnames(df_sub))
  missing_genes <- setdiff(target_genes, present_genes)
  if (length(present_genes) == 0) stop("None of target_genes are present in combined_df.")
  if (length(missing_genes) > 0) message("Dropping missing genes: ", paste(missing_genes, collapse = ", "))

  # Cell-level long table
  long <- df_sub %>%
    pivot_longer(cols = any_of(present_genes),
                 names_to = "gene", values_to = "expression") %>%
    mutate(group = .data[[sample]])

  # Dot summary (for plotting)
  dot_data <- long %>%
    group_by(gene, group) %>%
    summarise(
      avg_exp = mean(expression, na.rm = TRUE),
      pct_exp = sum(expression > expr_thresh, na.rm = TRUE) / n() * 100,
      n_cells = n(),
      .groups = "drop"
    )

  # --- leave-one-group-out mean ("others mean") per gene x group ---
  # For each gene:
  #   total_sum, total_n across all cells
  #   per-group sum_g, n_g
  #   others_mean = (total_sum - sum_g) / (total_n - n_g)
  totals <- long %>%
    group_by(gene) %>%
    summarise(
      total_sum = sum(expression, na.rm = TRUE),
      total_n   = sum(!is.na(expression)),
      .groups = "drop"
    )

  grp_sums <- long %>%
    group_by(gene, group) %>%
    summarise(
      sum_g = sum(expression, na.rm = TRUE),
      n_g   = sum(!is.na(expression)),
      .groups = "drop"
    )

  others_tbl <- grp_sums %>%
    left_join(totals, by = "gene") %>%
    mutate(
      n_others = total_n - n_g,
      others_mean = ifelse(n_others > 0, (total_sum - sum_g) / n_others, NA_real_)
    ) %>%
    select(gene, group, others_mean, n_others)

  # One-sample t-test per (gene, group) vs others_mean
  p_tbl <- long %>%
    left_join(others_tbl, by = c("gene", "group")) %>%
    group_by(gene, group) %>%
    summarise(
      p = {
        x <- expression
        mu <- others_mean[1]
        x <- x[is.finite(x)]
        if (length(x) < 3 || !is.finite(mu)) NA_real_ else suppressWarnings(t.test(x, mu = mu)$p.value)
      },
      .groups = "drop"
    )

  dot_data <- dot_data %>%
    left_join(others_tbl, by = c("gene", "group")) %>%
    left_join(p_tbl,     by = c("gene", "group")) %>%
    mutate(
      delta = avg_exp - others_mean,
      padj = p.adjust(p, method = p_adjust_method),
      highlight = case_when(
        is.na(padj) ~ FALSE,
        highlight_direction == "both" ~ (padj < alpha) & (abs(delta) > delta_min),
        highlight_direction == "up"   ~ (padj < alpha) & (delta >  delta_min),
        highlight_direction == "down" ~ (padj < alpha) & (delta < -delta_min)
      )
    )

  # Gene order
  dot_data$gene <- factor(dot_data$gene, levels = rev(target_genes))

  options(repr.plot.width = w, repr.plot.height = h)

  p_dot <- ggplot(dot_data, aes(x = group, y = gene)) +
    geom_point(aes(size = pct_exp, color = avg_exp)) +
    geom_point(
      data = filter(dot_data, highlight),
      aes(size = pct_exp),
      shape = 21, fill = NA, color = highlight_color, stroke = highlight_stroke,
      inherit.aes = TRUE
    ) +
    scale_color_gradientn(colors = c("white", endcolor)) +
    scale_size_continuous(range = c(0, 6), name = "% Expressed") +
    labs(
      x = "",
      y = "",
      color = "Avg. Expression",
      title = paste0(title, " (ring: adj p<", alpha, " vs mean of others)")
    ) +
    settheme +
    theme(
      axis.text.x = element_text(angle = 90, vjust = 0.5, hjust = 1),
      panel.border = element_rect(colour = "black", fill = NA, linewidth = 0.5),
      legend.position = "right"
    )

    ggsave( filename = sprintf("%s/A_%s_%s_dotplot.pdf", outdir, title, sample), plot =  p_dot, width = w, height = h)
    options(repr.plot.width=w, repr.plot.height=h)
    p_dot
}

# %% [markdown]
# ### plots - by sample

# %%
make_gene_dotplot(
  combined_df = combined_df,
  sample = "sample",
  target_genes = adhesion  ,
  w = 4, h = 5,
  title = "adhesion",
  endcolor = "#005AA3"
)
# Out:
# plot without title

# %%
make_gene_dotplot(
  combined_df = combined_df,
  sample = "sample",
  target_genes =  apoptosis,
  w = 4, h = 3,
  title = "apoptosis", 
  endcolor = "#87549B"
)
# Out:
# plot without title

# %%
make_gene_dotplot(
  combined_df = combined_df,
  sample = "sample",
  target_genes =  stress_response,
  w = 4, h = 4,
  title = "stress_response",
  endcolor = "#3F8F91"
)
# Out:
# plot without title

# %%
make_gene_dotplot(
  combined_df = combined_df,
  sample = "sample",
  target_genes =  non_intrisic_apoptosis,
  w = 4, h = 4,
  title = "stress_response",
  endcolor = "#3F8F91"
)
# Out:
# Dropping missing genes: TRAIL, TNFRSF6
# plot without title

# %% [markdown]
# ### plots - by celltype

# %%
make_gene_dotplot(
  combined_df = combined_df %>% subset(timepoint == "day6"),
  sample = "celltype_coarse",
  target_genes = adhesion  ,
  w = 2.5, h = 5,
  title = "adhesion_day6",
  endcolor = "#005AA3"
)
# Out:
# plot without title

# %%
make_gene_dotplot(
  combined_df = combined_df %>% subset(timepoint == "day6"),
  sample = "celltype_coarse",
  target_genes = adhesion_sub  ,
  w = 2.5, h = 3,
  title = "adhesion_day6",
  endcolor = "#005AA3"
)
# Out:
# plot without title

# %%
make_gene_dotplot(
  combined_df = combined_df %>% subset(timepoint == "day6"),
  sample = "celltype_coarse",
  target_genes = adhesion_sub  ,
  w = 2.5, h = 3,
  title = "adhesion_day6",
  endcolor = "#005AA3"
)
# Out:
# plot without title

# %%
head(combined_df)
# Out:
#   barcode dataset            cell.ID_
# 1 0       Embryo-Imp15265938 AAACCTGAGCGATCCC-1_Embryo-Imp15265938
# 2 3       Embryo-Imp15265938 AAACCTGCAATCACAC-1_Embryo-Imp15265938
# 3 5       Embryo-Imp15265938 AAACCTGCAGCTGCTG-1_Embryo-Imp15265938
# 4 6       Embryo-Imp15265938 AAACCTGCAGTGACAG-1_Embryo-Imp15265938
# 5 8       Embryo-Imp15265938 AAACCTGCATGTTGAC-1_Embryo-Imp15265938
# 6 9       Embryo-Imp15265938 AAACCTGGTAGCGTCC-1_Embryo-Imp15265938
#   scrublet_score scrublet_prediction scrublet_cluster_score scrublet_zscore
# 1 0.07129456     FALSE               0.08256881             -0.6249869
# 2 0.19064748     FALSE               0.19851577              0.5055552
# 3 0.22540984     FALSE               0.22540984              0.7677861
# 4 0.33522727     FALSE               0.21584158              0.6744908
# 5 0.20689655     FALSE               0.20689655              0.5872721
# 6 0.09309967     FALSE               0.08256881             -0.6249869
#   scrublet_bh_pval scrublet_bonf_pval n_genes_by_counts total_counts
# 1 1                0.9147751          4923              17150
# 2 1                0.8326981          8112              54075
# 3 1                0.8326981          8801              68329
# 4 1                0.8326981          7949              49264
# 5 1                0.8326981          7336              42984
# 6 1                0.9147751          7621              42425
#   total_counts_mt pct_counts_mt total_counts_ribo pct_counts_ribo n_genes_group
# 1  481            2.804665       4445             25.91837        low
# 2 1514            2.799815      13757             25.44059        high
# 3 1605            2.348929      17109             25.03915        high
# 4 1386            2.813413      12155             24.67319        high
# 5  860            2.000744      10845             25.23032        high
# 6 1402            3.304655      10427             24.57749        high
#   S_score      G2M_score   phase leiden mef_score  persample_celltype
# 1  0.291071261 -0.07524606 S     8       0.4381818 unknown
# 2 -0.046718237  0.36545115 G2M   0      -3.2758442 EPI
# 3 -0.044351377  0.21209913 G2M   0      -4.6309091 EPI
# 4 -0.009972636 -0.14632259 G1    0      -2.0374026 EPI
# 5 -0.003507561  0.16899508 G2M   0      -2.5353247 EPI
# 6  0.373325527  0.05538903 S     8       0.8384416 diff
#   sample_celltype sample     timepoint Condition State n_genes
# 1 low quality     T1_control day1      Control   Naïve 4923
# 2 EPI             T1_control day1      Control   Naïve 8112
# 3 EPI             T1_control day1      Control   Naïve 8801
# 4 EPI             T1_control day1      Control   Naïve 7949
# 5 EPI             T1_control day1      Control   Naïve 7336
# 6 TE              T1_control day1      Control   Naïve 7621
#   stress_score_vandenBrink leiden_theta0 leiden_theta1 leiden_theta2
# 1 0.3239384                11            2             1
# 2 0.2379417                 0            0             2
# 3 0.2474431                 0            0             3
# 4 0.3294210                 9            0             3
# 5 0.2769359                 0            0             2
# 6 0.3519634                 7            7             8
#   leiden_theta3 integrated_celltype leiden_lowres celltype_fine celltype_coarse
# 1 10            unspecified         7             unspecified_2 unspecified
# 2  4            naive EPI           1             EPI_1         EPI
# 3  1            naive EPI           1             EPI_1         EPI
# 4  1            naive EPI           1             EPI_1         EPI
# 5 -0.24436135                       -0.8950356
# 6  0.62254681                       -0.5024809
#   ESTROGEN_RESPONSE_LATE FATTY_ACID_METABOLISM G2M_CHECKPOINT GLYCOLYSIS
# 1 2.090937                2.19761463            4.672156      4.035323
# 2 1.877071                1.11408357           10.402252      6.648650
# 3 2.272842                1.66204396            8.665442      6.003446
# 4 1.981240               -0.05324457            5.522695      6.331321
# 5 2.813777               -1.51441673            7.608775      7.122286
# 6 1.942557                3.91450102            8.024313      5.843143
#   HEDGEHOG_SIGNALING HEME_METABOLISM HYPOXIA    IL2_STAT5_SIGNALING
# 1  0.4228610         2.310476        1.59357762 0.8073403
# 2 -1.3882767         2.744379        1.65562151 2.0877751
# 3 -1.3059116         2.201273        0.65214499 0.9355191
# 4 -1.3607286         3.257538        0.53887188 1.1951931
# 5 -1.2871638         3.015031        0.04024826 1.2660902
# 6  0.1369969         2.591325        1.17131631 1.3043772
#   IL6_JAK_STAT3_SIGNALING INFLAMMATORY_RESPONSE INTERFERON_ALPHA_RESPONSE
# 1 -2.3242783              -2.213566             1.160807
# 2 -0.6584493              -1.128698             2.333427
# 3 -0.9940268              -1.740197             2.607327
# 4 -0.5684108              -1.262758             2.575057
# 5 -0.8548638              -1.609571             1.663489
# 6 -1.9627982              -2.697356             1.328703
#   INTERFERON_GAMMA_RESPONSE KRAS_SIGNALING_DN KRAS_SIGNALING_UP MITOTIC_SPINDLE
# 1 -0.9937517                -2.447817         -1.636813          3.042325
# 2 -1.2928185                -1.486972         -1.774542         10.250077
# 3 -0.9395705                -2.626442         -2.508535          8.635455
# 4 -0.6371894                -2.406511         -1.623122          6.460000
# 5 -0.2624455                -2.795756         -2.469217          7.697811
# 6 -1.0943920                -2.558315         -2.281147          4.407254
#   MTORC1_SIGNALING MYC_TARGETS_V1 MYC_TARGETS_V2 MYOGENESIS NOTCH_SIGNALING
# 1  5.482511        40.41337       0.9440025      -0.6896662 1.4125454
# 2  9.848661        37.32849       0.3764290      -1.4134302 0.6148123
# 3  9.283367        42.58891       2.0307205      -0.9858143 0.8285152
# 4 10.926093        43.30139       1.1316159      -1.0911487 0.8053817
# 5 11.895131        42.15750       0.5165487      -0.9227510 1.1052978
# 6  7.199231        45.82969       1.1886325      -1.3997905 1.7846848
#   OXIDATIVE_PHOSPHORYLATION P53_PATHWAY PANCREAS_BETA_CELLS PEROXISOME
# 1 30.74954                  8.737676     2.20077576         0.2741485
# 2 27.70263                  5.925279    -0.43031334         2.3108136
# 3 34.41288                  8.091928    -0.08803849         2.2374482
# 4 32.27401                  7.710960     0.53807812         3.1786017
# 5 34.84578                  9.353687     0.06692801         2.3898489
# 6 31.18647                  6.286183     1.79723971         2.2472267
#   PI3K_AKT_MTOR_SIGNALING PROTEIN_SECRETION REACTIVE_OXYGEN_SPECIES_PATHWAY
# 1 5.855634                 9.039613          7.807055
# 2 5.823308                10.278359          6.709056
# 3 4.536209                 9.203366          9.259363
# 4 4.607585                10.443720         10.649505
# 5 4.248518                10.689687          9.132460
# 6 5.851685                 9.991693          9.016463
#   SPERMATOGENESIS TGF_BETA_SIGNALING TNFA_SIGNALING_VIA_NFKB
# 1  0.84911871     4.410874           -0.9749687
# 2  0.06862968     5.039883           -2.0331295
# 3 -0.76163867     4.645857           -2.0344124
# 4  0.40430285     4.115032           -0.9995399
# 5 -0.53455662     3.867135           -0.9888665
# 6 -0.03126961     2.609610           -0.9323944
#   UNFOLDED_PROTEIN_RESPONSE UV_RESPONSE_DN UV_RESPONSE_UP
# 1  7.658166                 0.3950144      4.561288
# 2 11.711983                 0.7935481      1.280116
# 3 11.696341                 0.6422843      1.922998
# 4 13.146498                 1.4000839      1.910147
# 5 14.862468                 0.2503796      3.327780
# 6 10.111446                 1.8857148      3.901106
#   WNT_BETA_CATENIN_SIGNALING XENOBIOTIC_METABOLISM
# 1 -2.1297247                 -0.1550725
# 2 -1.2663679                  0.7281318
# 3 -1.7834092                  1.2398202
# 4 -0.9054740                  1.4938179
# 5 -1.6467131                  2.0888628
# 6  0.3318068                 -1.5930503

# %%
make_gene_dotplot(
  combined_df = combined_df %>% subset(timepoint == "day6"),
  sample = "celltype_coarse",
  target_genes =  apoptosis,
  w = 2.7, h = 2.7,
  title = "apoptosis", 
  endcolor = "#87549B"
)
# Out:
# plot without title

# %%
make_gene_dotplot(
  combined_df = combined_df %>% subset(timepoint == "day1")%>% subset(celltype_coarse == "EPI"),
  sample = "ploidy",
  target_genes =  apoptosis,
  w = 2.7, h = 2.7,
  title = "apoptosis", 
  endcolor = "#87549B",
  
)
# Out:
# plot without title

# %%
make_gene_dotplot(
  combined_df = combined_df,
  sample = "celltype_coarse",
  target_genes =  stress_response,
  w = 2.7, h = 4,
  title = "stress_response",
  endcolor = "#3F8F91"
)
# Out:
# plot without title

# %% [markdown]
# ### plots- by ploidy

# %%
unique(combined_df$ploidy)
# Out:
# [1] diploid  trisomy  monosomy complex
# Levels: diploid trisomy monosomy complex

# %%
make_gene_dotplot(
  combined_df = combined_df%>% subset(timepoint == "day4")%>% subset(celltype_coarse == "unspecified"),
  sample = "ploidy",
  target_genes = adhesion  ,
  w = 2.8, h = 5,
  title = "adhesion",
  endcolor = "#005AA3"
)
# Out:
# plot without title

# %%
make_gene_dotplot(
  combined_df = combined_df,
  sample = "ploidy",
  target_genes =  apoptosis,
  w = 2.7, h = 2.7,
  title = "apoptosis", 
  endcolor = "#87549B"
)
# Out:
# plot without title

# %%
make_gene_dotplot(
  combined_df = combined_df,
  sample = "ploidy",
  target_genes =  stress_response,
  w = 2.7, h = 4,
  title = "stress_response",
  endcolor = "#3F8F91"
)
# Out:
# plot without title

# %%
make_gene_dotplot(
  combined_df = combined_df%>% subset(timepoint == "day4"),
  sample = "ploidy",
  target_genes =  EMT_genes,
  w = 2.7, h = 4,
  title = "EMT_response",
  endcolor = "#B165A0"
)
# Out:
# Dropping missing genes: TWIST
# plot without title

# %% [markdown]
# ## B_Dotplot (zscored)

# %% [markdown]
# ### function

# %%
make_gene_dotplot_zscored <- function(combined_df,
                              sample = "sample",
                              target_genes,
                              w = 4, h = 3,
                              title = "Gene Expression across Ploidy",
                              expr_thresh = 0, endcolor = "#3F8F91") {
    
  # Keep only columns we need 
  df_sub <- combined_df %>%
    select(all_of(sample), any_of(target_genes))

  # Check genes present
  present_genes <- intersect(target_genes, colnames(df_sub))
  missing_genes <- setdiff(target_genes, present_genes)
    
  if (length(missing_genes) > 0) {
    message("Dropping missing genes: ", paste(missing_genes, collapse = ", "))
  }

  # Summarise for dotplot
  dot_data <- df_sub %>%
    pivot_longer(
      cols = any_of(present_genes),
      names_to = "gene",
      values_to = "expression"
    ) %>%
    group_by(gene, .data[[sample]]) %>%
    summarise(
      avg_exp = mean(expression, na.rm = TRUE),
      pct_exp = sum(expression > expr_thresh, na.rm = TRUE) / n() * 100,
      .groups = "drop"
    )%>%
      group_by(gene) %>%
      mutate(
        avg_exp_z = as.numeric(scale(avg_exp))   # (x - mean)/sd within gene
      ) %>%
      ungroup()

  # Gene order (top-to-bottom = target_genes order reversed)
  dot_data$gene <- factor(dot_data$gene, levels = rev(target_genes))

  # Plot size 
  options(repr.plot.width = w, repr.plot.height = h)

  p_dot <- ggplot(dot_data, aes(x = .data[[sample]], y = gene)) +
    geom_point(aes(size = pct_exp, color = avg_exp_z)) +
    scale_color_gradientn(colors = c("white", endcolor)) +
    scale_size_continuous(range = c(0, 6), name = "% Expressed") +
    labs(
      x = "",
      y = "",
      color = "z-score",
      title = sprintf("%s_z-scored", title)
    ) +
    settheme +
    theme(
      axis.text.x = element_text(angle = 90, vjust = 0.5, hjust = 1),
      panel.border = element_rect(colour = "black", fill = NA, linewidth = 0.5),
      legend.position = "right"
    )


    ggsave( filename = sprintf("%s/B_%s_%s_dotplot_zscored.pdf", outdir, title, sample), plot =  p_dot, width = w, height = h)
    options(repr.plot.width=w, repr.plot.height=h)
    p_dot
}

# %% [markdown]
# ### plots - by sample

# %%
make_gene_dotplot_zscored(
  combined_df = combined_df,
  sample = "sample",
  target_genes = adhesion  ,
  w = 4, h = 5,
  title = "adhesion",
  endcolor = "#005AA3"
)
# Out:
# plot without title

# %%
make_gene_dotplot_zscored(
  combined_df = combined_df,
  sample = "sample",
  target_genes =  apoptosis,
  w = 4, h = 3,
  title = "apoptosis", 
  endcolor = "#87549B"
)
# Out:
# plot without title

# %%
make_gene_dotplot_zscored(
  combined_df = combined_df,
  sample = "sample",
  target_genes =  stress_response,
  w = 4, h = 4,
  title = "stress_response",
  endcolor = "#3F8F91"
)
# Out:
# plot without title

# %% [markdown]
# ### plots- by celltype

# %%
make_gene_dotplot_zscored(
  combined_df = combined_df,
  sample = "celltype_coarse",
  target_genes = adhesion  ,
  w = 2.5, h = 5,
  title = "adhesion_all",
  endcolor = "#005AA3"
)
# Out:
# plot without title

# %%
make_gene_dotplot_zscored(
  combined_df = combined_df %>% subset(timepoint == "day6"),
  sample = "celltype_coarse",
  target_genes = adhesion_sub2,
  w = 2.5, h = 2.8,
  title = "adhesion_D6",
  endcolor = "#B165A0"
)
# Out:
# plot without title

# %%
make_gene_dotplot_zscored(
  combined_df = combined_df%>%subset(timepoint == "day1"),
  sample = "ploidy",
  target_genes = adhesion  ,
  w = 2.8, h = 5,
  title = "adhesion_day1",
  endcolor = "#005AA3"
)
# Out:
# plot without title

# %%
make_gene_dotplot_zscored(
  combined_df = combined_df%>%subset(timepoint == "day1"),
  sample = "ploidy",
  target_genes = adhesion_sub  ,
  w = 2.5, h = 3.2,
  title = "adhesion_day1",
  endcolor = "#005AA3"
)
# Out:
# plot without title

# %%
make_gene_dotplot_zscored(
  combined_df = combined_df %>% subset(timepoint == "day4"),
  sample = "ploidy",
  target_genes = adhesion_sub ,
  w = 2.5, h = 3.2,
  title = "adhesion_D4",
  endcolor = "#005AA3"
)
# Out:
# plot without title

# %%
make_gene_dotplot_zscored(
  combined_df = combined_df %>% subset(timepoint == "day4"),
  sample = "ploidy",
  target_genes = adhesion ,
  w = 2.8, h = 5,
  title = "adhesion_D4",
  endcolor = "#005AA3"
)
# Out:
# plot without title

# %%
make_gene_dotplot_zscored(
  combined_df = combined_df %>% subset(timepoint == "day1"),
  sample = "ploidy",
  target_genes =  apoptosis,
  w = 2.7, h = 2.7,
  title = "apoptosis_day1", 
  endcolor = "#87549B"
)
# Out:
# plot without title

# %%
make_gene_dotplot_zscored(
  combined_df = combined_df %>% subset(timepoint == "day4"),
  sample = "ploidy",
  target_genes =  TE_genes,
  w = 2.7, h = 2.7,
  title = "TEgenes_day4", 
  endcolor = "#87549B"
)
# Out:
# plot without title

# %%
make_gene_dotplot_zscored(
  combined_df = combined_df%>% subset(timepoint == "day4")%>% subset(celltype_coarse == "unspecified"),
  sample = "ploidy",
  target_genes =  EPI_genes,
  w = 2.7, h = 2.7,
  title = "EPIgenes_day4",
  endcolor = "#3F8F91"
)
# Out:
# plot without title

# %%
make_gene_dotplot_zscored(
  combined_df = combined_df%>% subset(timepoint == "day4"),
  sample = "ploidy",
  target_genes =  non_intrisic_apoptosis,
  w = 2.7, h = 2.7,
  title = "extrinsic_apopotosis_day4",
  endcolor = "#3F8F91"
)
# Out:
# Dropping missing genes: TRAIL, TNFRSF6
# plot without title

# %%
make_gene_dotplot_zscored(
  combined_df = combined_df%>% subset(timepoint == "day4")%>% subset(ploidy == "complex"),
  sample = "Condition",
  target_genes =  non_intrisic_apoptosis,
  w = 2.7, h = 2.7,
  title = "extrinsic_apopotosis_day4",
  endcolor = "#3F8F91"
)
# Out:
# Dropping missing genes: TRAIL, TNFRSF6
# plot without title

# %%
colnames(combined_df)
# Out:
#   [1] "barcode"                           "dataset"
#   [3] "cell.ID_"                          "scrublet_score"
#   [5] "scrublet_prediction"               "scrublet_cluster_score"
#   [7] "scrublet_zscore"                   "scrublet_bh_pval"
#   [9] "scrublet_bonf_pval"                "n_genes_by_counts"
#  [11] "total_counts"                      "total_counts_mt"
#  [13] "pct_counts_mt"                     "total_counts_ribo"
#  [15] "pct_counts_ribo"                   "n_genes_group"
#  [17] "S_score"                           "G2M_score"
#  [19] "phase"                             "leiden"
#  [21] "mef_score"                         "persample_celltype"
#  [23] "sample_celltype"                   "sample"
#  [25] "timepoint"                         "Condition"
#  [27] "State"                             "n_genes"
#  [29] "stress_score_vandenBrink"          "leiden_theta0"
#  [31] "leiden_theta1"                     "leiden_theta2"
#  [33] "leiden_theta3"                     "integrated_celltype"
#  [35] "leiden_lowres"                     "celltype_fine"
#  [37] "celltype_coarse"                   "UMAP1"
#  [39] "UMAP2"                             "AEN"
#  [41] "RPS27L"                            "GPX1"
#  [43] "EDA2R"                             "CDKN1A"
#  [45] "RRM2B"                             "BCL2L13"
#  [47] "CALM3"                             "SESN1"
#  [49] "POLH"                              "DDB2"
#  [51] "PPM1D"                             "KCNK1"
#  [53] "MDM2"                              "PLK2"
#  [55] "CEP63"                             "NUCKS1"
#  [57] "GTF2H5"                            "ATP6V0A2"
#  [59] "PLEKHA1"                           "CDH1"
#  [61] "TJP1"                              "ACTB"
#  [63] "ACTG1"                             "ITGB1"
#  [65] "ITGA6"                             "ITGAV"
#  [67] "ITGB5"                             "NECTIN2"
#  [69] "F11R"                              "CDH3"
#  [71] "EPCAM"                             "DSG2"
#  [73] "GJA1"                              "OCLN"
#  [75] "PVR"                               "NECTIN1"
#  [77] "BCAM"                              "ICAM1"
#  [79] "ITGA9"                             "CLDN1"
#  [81] "ITGA2"                             "CXADR"
#  [83] "GATA2"                             "GATA3"
#  [85] "CDX2"                              "TFAP2C"
#  [87] "KRT7"                              "KRT18"
#  [89] "OVOL1"                             "POU5F1"
#  [91] "GDF3"                              "ARGFX"
#  [93] "NANOG"                             "SOX2"
#  [95] "KLF17"                             "TDGF1"
#  [97] "CDH2"                              "SNAI1"
#  [99] "SNAI2"                             "ZEB1"
# [101] "ZEB2"                              "VIM"
# [103] "FASLG"                             "TNF"
# [105] "TNFSF10"                           "FAS"
# [107] "TNFRSF1A"                          "TNFRSF10A"
# [109] "TNFRSF10B"                         "cell"
# [111] "...1"                              "karyotype"
# [113] "ploidy"                            "num_gain_chr"
# [115] "num_loss_chr"                      "num_chr"
# [117] "num_abnormal_chr"                  "Androgen"
# [119] "EGFR"                              "Estrogen"
# [121] "Hypoxia"                           "JAK-STAT"
# [123] "MAPK"                              "NFkB"
# [125] "PI3K"                              "TGFb"
# [127] "TNFa"                              "Trail"
# [129] "VEGF"                              "WNT"
# [131] "p53"                               "ADIPOGENESIS"
# [133] "ALLOGRAFT_REJECTION"               "ANDROGEN_RESPONSE"
# [135] "ANGIOGENESIS"                      "APICAL_JUNCTION"
# [137] "APICAL_SURFACE"                    "APOPTOSIS"
# [139] "BILE_ACID_METABOLISM"              "CHOLESTEROL_HOMEOSTASIS"
# [141] "COAGULATION"                       "COMPLEMENT"
# [143] "DNA_REPAIR"                        "E2F_TARGETS"
# [145] "EPITHELIAL_MESENCHYMAL_TRANSITION" "ESTROGEN_RESPONSE_EARLY"
# [147] "ESTROGEN_RESPONSE_LATE"            "FATTY_ACID_METABOLISM"
# [149] "G2M_CHECKPOINT"                    "GLYCOLYSIS"
# [151] "HEDGEHOG_SIGNALING"                "HEME_METABOLISM"
# [153] "HYPOXIA"                           "IL2_STAT5_SIGNALING"
# [155] "IL6_JAK_STAT3_SIGNALING"           "INFLAMMATORY_RESPONSE"
# [157] "INTERFERON_ALPHA_RESPONSE"         "INTERFERON_GAMMA_RESPONSE"
# [159] "KRAS_SIGNALING_DN"                 "KRAS_SIGNALING_UP"
# [161] "MITOTIC_SPINDLE"                   "MTORC1_SIGNALING"
# [163] "MYC_TARGETS_V1"                    "MYC_TARGETS_V2"
# [165] "MYOGENESIS"                        "NOTCH_SIGNALING"
# [167] "OXIDATIVE_PHOSPHORYLATION"         "P53_PATHWAY"
# [169] "PANCREAS_BETA_CELLS"               "PEROXISOME"
# [171] "PI3K_AKT_MTOR_SIGNALING"           "PROTEIN_SECRETION"
# [173] "REACTIVE_OXYGEN_SPECIES_PATHWAY"   "SPERMATOGENESIS"
# [175] "TGF_BETA_SIGNALING"                "TNFA_SIGNALING_VIA_NFKB"
# [177] "UNFOLDED_PROTEIN_RESPONSE"         "UV_RESPONSE_DN"
# [179] "UV_RESPONSE_UP"                    "WNT_BETA_CATENIN_SIGNALING"
# [181] "XENOBIOTIC_METABOLISM"

# %%
combined_df$condition_ploidy = paste(combined_df$ploidy ,combined_df$Condition, sep = "_")

# %%
make_gene_dotplot_zscored(
  combined_df = combined_df%>% subset(timepoint == "day4"),
  sample = "condition_ploidy",
  target_genes =  non_intrisic_apoptosis,
  w =5, h = 5,
  title = "extrinsic_apopotosis_day4",
  endcolor = "#3F8F91"
)
# Out:
# Dropping missing genes: TRAIL, TNFRSF6
# plot without title

# %%
make_gene_dotplot_zscored(
  combined_df = combined_df,
  sample = "celltype_coarse",
  target_genes =  stress_response,
  w = 2.7, h = 4,
  title = "stress_response",
  endcolor = "#3F8F91"
)
# Out:
# plot without title

# %%
make_gene_dotplot_zscored(
  combined_df = combined_df%>% subset(timepoint == "day4"),
  sample = "ploidy",
  target_genes =  EMT_genes,
  w = 2.7, h = 3,
  title = "EMT_response",
  endcolor = "#B165A0"
)
# Out:
# Dropping missing genes: TWIST
# plot without title

# %% [markdown]
# ### per chr

# %%
library(dplyr)
library(stringr)

# 1. Define the specific chromosomes you want to detect
# We wrap them in word boundaries (\\b) so '4+' doesn't match inside '14+'
target_pattern <- "\\b(13|22|14|15|19|9|)\\+"

combined_df <- combined_df %>%
  mutate(developed_karyo = case_when(
    # 1. Exact match for diploid
    karyotype == "diploid" ~ "diploid",
    
    # 2. Check for specific developed chromosomes
    # This regex looks for 7, 13, 4, etc. followed immediately by a +
    str_detect(karyotype, target_pattern) & ploidy == "trisomy" ~ "aneu_developed",
    
    # 3. Everything else (including 14+, 17+, etc.)
    TRUE ~ "aneu_failed"
  ))

# %%
developed_pattern <- "(^|,\\s*)(13\\+|22\\+|14\\+|19\\+|15\\+|9\\+|11\\-)(?=,|$)"
failed_pattern    <- "(^|,\\s*)(17\\-|22\\-|6\\-|19\\-|12\\-|12\\+|21\\-)(?=,|$)"

combined_df <- combined_df %>%
  mutate(
    is_euploid = ploidy == "diploid",
    is_trisomy = ploidy == "trisomy",
    
    dev_hit = str_detect(karyotype, developed_pattern),
    fail_hit = str_detect(karyotype, failed_pattern),
    
    CLR_enrichment = case_when(
      is_euploid ~ "euploid",
      dev_hit & !fail_hit ~ "Developed_enriched",
      fail_hit & !dev_hit ~ "Failed_enriched",
      TRUE ~ "others_aneuploid"
    ),
    
    CLR_enrichment = factor(
      CLR_enrichment,
      levels = c( "euploid", "Developed_enriched", "Failed_enriched", "others_aneuploid")
    )
  ) %>%
  select(-is_euploid, -is_trisomy, -dev_hit, -fail_hit)

# %%
developed_pattern <- "(^|,\\s*)(13\\+|22\\+|14\\+|19\\+|15\\+|9\\+|6\\+)(?=,|$)"
failed_pattern    <- "(^|,\\s*)(12\\+|5\\+|7\\+|2\\+|4\\+|20\\+|17\\+)(?=,|$)"

combined_df2 <- combined_df %>%
  mutate(
    is_euploid = ploidy == "diploid",
    is_trisomy = ploidy == "trisomy",
    
    dev_hit = is_trisomy & str_detect(karyotype, developed_pattern),
    fail_hit = is_trisomy & str_detect(karyotype, failed_pattern),
    
    CLR_enrichment_Trisomy = case_when(
      is_euploid ~ "euploid",
      dev_hit & !fail_hit ~ "Developed_enriched",
      fail_hit & !dev_hit ~ "Failed_enriched",
      TRUE ~ "others_aneuploid"
    ),
    
    CLR_enrichment_Trisomy = factor(
      CLR_enrichment_Trisomy,
      levels = c("euploid", "Developed_enriched", "Failed_enriched", "others_aneuploid")
    )
  ) %>%
  select(-is_euploid, -is_trisomy, -dev_hit, -fail_hit)

# %%
# --- Verification Step (Optional) ---
# Check specific examples to make sure logic holds
test_cases <- combined_df %>%
  filter(karyotype %in% c("17-") )%>%
  select(karyotype, CLR_enrichment)

print(test_cases)
# Out:
# # A tibble: 199 × 2
#    karyotype CLR_enrichment
#    <chr>     <fct>
#  1 17-       Failed_enriched
#  2 17-       Failed_enriched
#  3 17-       Failed_enriched
#  4 17-       Failed_enriched
#  5 17-       Failed_enriched
#  6 17-       Failed_enriched
#  7 17-       Failed_enriched
#  8 17-       Failed_enriched
#  9 17-       Failed_enriched
# 10 17-       Failed_enriched
# # ℹ 189 more rows

# %%
make_gene_dotplot_zscored(
  combined_df = combined_df %>% subset(timepoint == "day4"),
  sample = "CLR_enrichment",
  target_genes = adhesion,
  w = 2.8, h = 7,
  title = "adhesion_D4",
  endcolor = "#005AA3"
)
# Out:
# plot without title

# %%
make_gene_dotplot_zscored(
  combined_df = combined_df %>% subset(timepoint == "day4"),
  sample = "CLR_enrichment",
  target_genes = adhesion_sub,
  w = 2.8, h = 4,
  title = "adhesionsub_D4",
  endcolor = "#005AA3"
)
# Out:
# plot without title

# %%
make_gene_dotplot_zscored(
  combined_df = combined_df %>% subset(timepoint == "day4"),
  sample = "CLR_enrichment",
  target_genes =  EPI_genes,
  w = 2.7, h = 3,
  title = "EPIgenes",
  endcolor = "#3F8F91"
)
# Out:
# plot without title

# %%
make_gene_dotplot_zscored(
  combined_df = combined_df %>% subset(timepoint == "day4"),
  sample = "CLR_enrichment",
  target_genes =  TE_genes,
  w = 2.7, h = 2.7,
  title = "TEgenes_day4", 
  endcolor = "#87549B"
)
# Out:
# plot without title

# %%
make_gene_dotplot_zscored(
  combined_df = combined_df %>% subset(timepoint == "day4")%>% subset(CLR_enrichment != "others_aneuploid"),
  sample = "CLR_enrichment",
  target_genes = adhesion_sub2,
  w = 2.5, h = 3,
  title = "D4",
  endcolor = "#B165A0"
)
# Out:
# plot without title

# %%
make_gene_dotplot_zscored(
  combined_df = combined_df%>% subset(timepoint == "day4")%>% subset(CLR_enrichment != "others_aneuploid"),
  sample = "CLR_enrichment",
  target_genes =  EMT_genes,
  w = 2.5, h = 3,
  title = "EMT_response",
  endcolor = "#B165A0"
)
# Out:
# Dropping missing genes: TWIST
# plot without title

# %%
make_gene_dotplot_zscored(
  combined_df = combined_df %>% subset(timepoint == "day4")%>% subset(CLR_enrichment != "others_aneuploid"),
  sample = "CLR_enrichment",
  target_genes =  EPI_genes,
  w = 2.5, h = 3,
  title = "EPIgenes",
  endcolor = "#3F8F91"
)
# Out:
# plot without title

# %%
make_gene_dotplot_zscored(
  combined_df = combined_df %>% subset(timepoint == "day4")%>% subset(CLR_enrichment != "others_aneuploid"),
  sample = "CLR_enrichment",
  target_genes =  TE_genes,
  w = 2.7, h = 2.7,
  title = "TEgenes_day4", 
  endcolor = "#87549B"
)
# Out:
# plot without title

# %%
make_gene_dotplot_zscored(
  combined_df = combined_df2 %>% subset(timepoint == "day4"),
  sample = "CLR_enrichment_Trisomy",
  target_genes = adhesion_sub ,
  w = 2.8, h = 5,
  title = "adhesion_D4",
  endcolor = "#005AA3"
)
# Out:
# plot without title

# %%
make_gene_dotplot_zscored(
  combined_df = combined_df%>% subset(timepoint == "day4"),
  sample = "CLR_enrichment",
  target_genes =  EMT_genes,
  w = 2.7, h = 4,
  title = "EMT_response",
  endcolor = "#3F8F91"
)
# Out:
# Dropping missing genes: TWIST
# plot without title

# %%
make_gene_dotplot_zscored(
  combined_df = combined_df2%>% subset(timepoint == "day4"),
  sample = "CLR_enrichment",
  target_genes =  EPI_genes,
  w = 2.7, h = 2.7,
  title = "EPIgenes_day4",
  endcolor = "#3F8F91"
)
# Out:
# plot without title

# %%
make_gene_dotplot_zscored(
  combined_df = combined_df %>% subset(timepoint == "day4"),
  sample = "CLR_enrichment",
  target_genes =  TE_genes,
  w = 2.7, h = 2.7,
  title = "TEgenes_day4", 
  endcolor = "#87549B"
)
# Out:
# plot without title

# %% [markdown]
# ## C_Heatmap

# %% [markdown]
# ### function

# %%
make_gene_heatmap <- function(combined_df,
                              sample = "sample",
                              facet_col = NULL,                 # optional facet column
                              target_genes,
                              w = 4, h = 3,
                              title = "Gene Expression across Ploidy",
                              endcolor = "#3F8F91",
                              zscore_within_celltype = FALSE,   # used only if faceting
                              zscore = FALSE,
                              facet_scales = "fixed",
                             col_palette= "RdPu") {         # expose scales option

  # decide if we can facet
  use_facet <- !is.null(facet_col) && facet_col %in% names(combined_df)

  # columns to keep
  keep_cols <- c(sample, target_genes)
  if (use_facet) keep_cols <- c(facet_col, keep_cols)

  df_sub <- combined_df %>% select(all_of(keep_cols))

  # gene presence check
  present_genes <- intersect(target_genes, colnames(df_sub))
  missing_genes <- setdiff(target_genes, present_genes)
  if (length(missing_genes) > 0) {
    message("Dropping missing genes: ", paste(missing_genes, collapse = ", "))
  }

  # summarise per gene × sample [× facet]
  group_vars <- c("gene", sample)
  if (use_facet) group_vars <- c(group_vars, facet_col)

  dot_data <- df_sub %>%
    pivot_longer(cols = any_of(present_genes),
                 names_to = "gene", values_to = "expression") %>%
    group_by(across(all_of(group_vars))) %>%
    summarise(
      avg_exp = mean(expression, na.rm = TRUE),
      .groups = "drop"
    ) %>%
    {
      if (zscore) {
        if (use_facet && zscore_within_celltype) {
          group_by(., gene, .data[[facet_col]])
        } else {
          group_by(., gene)
        }
      } else .
    } %>%
    { if (zscore) mutate(., avg_exp_z = as.numeric(scale(avg_exp))) else . } %>%
    ungroup()

  # order genes as given (top-to-bottom)
  dot_data$gene <- factor(dot_data$gene, levels = rev(target_genes))

  # plot
  options(repr.plot.width = w, repr.plot.height = h)
  fill_var <- if (isTRUE(zscore)) "avg_exp_z" else "avg_exp"
  zstring  <- if (isTRUE(zscore)) "_zscored" else ""

  p <- ggplot(dot_data, aes(x = .data[[sample]], y = gene)) +
    geom_tile(aes(fill = .data[[fill_var]]), color = "black") +
     scale_fill_distiller(
  palette = col_palette , type = "seq", direction = 1,
  na.value = "grey90",
  oob = scales::squish
)+
    labs(x = "", y = "", title = sprintf("%s%s", title, zstring)) +
    settheme +
    theme(
      axis.text.x = element_text(angle = 90, vjust = 0.5, hjust = 1),
      axis.ticks.x = element_line(),
      strip.background = element_blank(),
      panel.background = element_rect(fill = "#E0E0E0"),
      panel.grid = element_blank(),
      legend.position = "right",
      axis.line = element_blank(),
      panel.border = element_blank()
    )

  # add facet only if requested and valid
  if (use_facet) {
    p <- p + facet_wrap(vars(!!sym(facet_col)), scales = facet_scales)
  } else if (!is.null(facet_col) && !facet_col %in% names(combined_df)) {
    warning(sprintf("facet_col='%s' not found; skipping faceting.", facet_col))
  }

  ggsave(filename = sprintf("%s/C_%s%s_%s_heatmap.pdf", outdir, title, zstring, sample),
         plot = p, width = w, height = h)
  p
}

# %% [markdown]
# ### plots

# %%
make_gene_heatmap(
  combined_df = combined_df %>% subset(timepoint == "day1")%>% subset(celltype_coarse == "EPI"),
  sample = "ploidy",
  facet_col = "celltype_coarse", 
  target_genes = mlm_PROGENy_var  ,
  w = 2.2, h = 3,
  title = "mlm_PROGENy_day1",
  endcolor = "#D24D63",
  zscore = TRUE,
  zscore_within_celltype = TRUE
)
# Out:
# plot without title

# %%
make_gene_heatmap(
  combined_df = combined_df %>%
    filter(
      timepoint == "day1",
      #celltype_coarse == "EPI",
      Condition %in% c("Control", "Reversine")
    ) %>%
    mutate(
      condition_ploidy = interaction(
        Condition,
        ploidy,
        sep = "_",
        drop = TRUE
      )
    ),
  sample = "condition_ploidy",
  #facet_col = "celltype_coarse",
  target_genes = mlm_PROGENy_var,
  w = 3.5,
  h = 4,
  title = "mlm_PROGENy_day1_by_condition_ploidy",
  endcolor = "#D24D63",
  zscore = TRUE,
  zscore_within_celltype = FALSE,
 col_palette= "YlGnBu"
)
# Out:
# plot without title

# %%
make_gene_heatmap(
  combined_df = combined_df %>% subset(timepoint == "day4")%>% subset(celltype_coarse == "unspecified"),
  sample = "ploidy",
  facet_col = "celltype_coarse", 
  target_genes = mlm_PROGENy_var  ,
  w = 2.2, h = 3,
  title = "mlm_PROGENy_day4",
  endcolor = "#D24D63",
  zscore = TRUE,
  zscore_within_celltype = TRUE
)
# Out:
# plot without title

# %%
make_gene_heatmap(
  combined_df = combined_df %>% subset(timepoint == "day4")%>% subset(celltype_coarse == "unspecified"),
  sample = "ploidy",
  facet_col = "celltype_coarse", 
  target_genes = mlm_PROGENy_var  ,
  w = 2.2, h = 3,
  title = "mlm_PROGENy_day4",
  endcolor = "#D24D63",
  zscore = TRUE,
  zscore_within_celltype = TRUE
)
# Out:
# plot without title

# %%
make_gene_heatmap(
  combined_df = combined_df %>% subset(timepoint == "day6"),
  sample = "celltype_coarse",
  #facet_col = "celltype_coarse", 
  target_genes = mlm_PROGENy_var  ,
  w = 2.2, h = 3,
  title = "mlm_PROGENy_day6_celltype",
  endcolor = "#D24D63",
  zscore = TRUE,
  zscore_within_celltype = TRUE
)
# Out:
# plot without title

# %%
make_gene_heatmap(
  combined_df = combined_df %>% subset(timepoint == "day6"),
  sample = "ploidy",
  facet_col = "celltype_coarse", 
  target_genes = mlm_PROGENy_var  ,
  w = 3.7, h = 3,
  title = "mlm_PROGENy_day6",
  endcolor = "#D24D63",
  zscore = TRUE,
  zscore_within_celltype = TRUE
)
# Out:
# plot without title

# %%
make_gene_heatmap(
  combined_df = combined_df,
  sample = "celltype_coarse",
  facet_col = NULL, 
  target_genes = mlm_PROGENy_var  ,
  w = 3.7, h = 3,
  title = "mlm_PROGENy_celltype",
  endcolor = "#D24D63",
  zscore = TRUE,
  zscore_within_celltype = FALSE
)
# Out:
# plot without title

# %%
make_gene_heatmap(
  combined_df = combined_df %>% subset(timepoint == "day1") %>% subset(celltype_coarse == "EPI"),
  sample = "ploidy",
  facet_col = "celltype_coarse", 
  target_genes = mlm_hallmark_var  ,
  w = 3.7, h = 6,
  title = "mlm_hallmark_day1",
  endcolor = "#66437F",
  zscore = TRUE,
  zscore_within_celltype = TRUE,
 col_palette= "YlGnBu"
)
# Out:
# plot without title

# %%
make_gene_heatmap(
  combined_df = combined_df %>% subset(timepoint == "day4") %>% subset(celltype_coarse == "unspecified"),
  sample = "ploidy",
  facet_col = "celltype_coarse", 
  target_genes = mlm_hallmark_var  ,
  w = 3.7, h = 6,
  title = "mlm_hallmark_day4",
  endcolor = "#66437F",
  zscore = TRUE,
  zscore_within_celltype = TRUE,
 col_palette= "YlGnBu"
)
# Out:
# plot without title

# %%
make_gene_heatmap(
  combined_df = combined_df %>% subset(timepoint == "day4")%>% subset(CLR_enrichment != "others_aneuploid"),
  sample = "CLR_enrichment",
  #facet_col = "celltype_coarse", 
  target_genes = mlm_hallmark_var  ,
  w = 3.7, h = 6,
  title = "mlm_hallmark_CLR_enrichment_day4",
  endcolor = "#D24D63",
  zscore = TRUE,
  zscore_within_celltype = TRUE
)
# Out:
# plot without title

# %%
make_gene_heatmap(
  combined_df = combined_df %>% subset(timepoint == "day6"),
  sample = "celltype_coarse",
  facet_col = "timepoint", 
  target_genes = mlm_hallmark_var  ,
  w = 3.7, h = 6,
  title = "mlm_hallmark_day6",
  endcolor = "#66437F",
  zscore = TRUE,
  zscore_within_celltype = TRUE,
 col_palette= "YlGnBu"
)
# Out:
# plot without title

# %%
make_gene_heatmap(
  combined_df = combined_df %>% subset(timepoint == "day6"),
  sample = "ploidy",
  facet_col = "celltype_coarse", 
  target_genes = mlm_hallmark_var  ,
  w = 5, h = 6,
  title = "mlm_hallmark_day6",
  endcolor = "#66437F",
  zscore = TRUE,
  zscore_within_celltype = TRUE,
 col_palette= "YlGnBu"
)
# Out:
# plot without title

# %%
make_gene_heatmap(
  combined_df = combined_df %>% subset(timepoint == "day6"),
  sample = "ploidy",
  facet_col = "celltype_coarse", 
  target_genes = TE_genes  ,
  w = 5, h = 3,
  title = "mlm_hallmark_day6",
  endcolor = "#66437F",
  zscore = TRUE,
  zscore_within_celltype = FALSE,
 col_palette= "YlGnBu"
)
# Out:
# plot without title

# %% [markdown]
# ## Boxplot

# %%
plot_genes = stress_response

# %%
#reformat
plot_data_long <- combined_df %>%
  pivot_longer(
    cols = any_of(plot_genes), # Select the gene columns
    names_to = "gene", 
    values_to = "expression"
  )

#plot
title = "genes_expression"

w <- 10
h <- 2
options(repr.plot.width=w, repr.plot.height=h)

# 2. Create the Plot
p <- ggplot(plot_data_long, aes(x = sample, y = expression, fill = sample, color = sample )) +
  # Add the boxplot layer (hiding outliers because we add them with jitter)
  geom_boxplot(outlier.shape = NA, alpha = 0.5, width = 0.6) +
  
  # Add the jittered dots
  geom_jitter(width = 0.2, size = 0.1, alpha = 0.2) +
  
  # Facet by gene
  facet_wrap(~gene, scales = "free_y", nrow = 1) +
  
  # Labels and Theme
  labs(
    title = title,
    x = "Sample",
    y = "Log-Normalized Expression"
  ) +
  settheme + # Your custom lab theme
  theme(
    axis.text.x = element_text(angle = 45, hjust = 1),
    legend.position = "none"
  )+scale_fill_manual(values=color_sample)+
  scale_color_manual(values=color_sample)

# Save and Display
#ggsave(file.path(out_dir, "gene_boxplot_per_sample.pdf"), plot = p, width = 6, height = 4)
p
# Out:
# plot without title

# %%
plot_genes =  c("n_genes_by_counts","pct_counts_mt")

#reformat
plot_data_long <- combined_df %>%
  pivot_longer(
    cols = any_of(plot_genes), # Select the gene columns
    names_to = "gene", 
    values_to = "expression"
  )

#plot
title = "QC_celltype"

w <- 2
h <- 2
options(repr.plot.width=w, repr.plot.height=h)

# 2. Create the Plot
p <- ggplot(plot_data_long, aes(x = celltype_coarse, y = expression, fill = celltype_coarse, color = celltype_coarse))+
   geom_boxplot(outlier.shape = NA, alpha = 0.5, width = 0.6) +
  
  # Add the jittered dots
 # geom_jitter(width = 0.2, size = 0.1, alpha = 0.1) +
  
  # Facet by gene
  facet_wrap(~gene, scales = "free_y", nrow = 1) +
  
  # Labels and Theme
  labs(
    title = title,
    x = "",
   # y = "Log-Normalized Expression"
  ) +
  # mean ± SE
  stat_summary(fun = mean, geom = "point", size = 0.5, colour = "grey20") +
  stat_summary(fun.data = mean_se, geom = "errorbar", width = 0.15, colour = "grey20") +
  labs(
    #x = "Sample",
    #y = "% aneuploid cells/embryo"
  ) +
  settheme + # Your custom lab theme
  theme(
    axis.text.x = element_text(angle = 45, hjust = 1),
    legend.position = "none"
  )+scale_fill_manual(values=color_celltype)+
  scale_color_manual(values=color_celltype)
# Save and Display
  ggsave(filename = sprintf("%s/D_%s_boxplot.pdf", outdir, title),
         plot = p, width = w, height = h)
p
# Out:
# plot without title

# %%
plot_genes =  c("n_genes_by_counts","pct_counts_mt", "stress_score_vandenBrink")

#reformat
plot_data_long <- combined_df %>%
  pivot_longer(
    cols = any_of(plot_genes), # Select the gene columns
    names_to = "gene", 
    values_to = "expression"
  )

plot_data_long_sub = plot_data_long %>% filter(Condition == "Control")

#plot
title = "QC_celltype_control"

w <- 3
h <- 2
options(repr.plot.width=w, repr.plot.height=h)

# 2. Create the Plot
p <- ggplot(plot_data_long_sub, aes(x = celltype_coarse, y = expression, fill = celltype_coarse, color = celltype_coarse))+
  
  # Add the jittered dots
 geom_jitter(width = 0.2, size = 0.05, alpha = 0.05) +

 geom_boxplot(outlier.shape = NA, alpha = 0.5, width = 0.6,linewidth = LINE.W,
    color = "black" ) +
  
  # Facet by gene
  facet_wrap(~gene, scales = "free_y", nrow = 1) +
  
  # Labels and Theme
  labs(
    title = title,
    x = "",
   # y = "Log-Normalized Expression"
  ) +
  # mean ± SE
  #stat_summary(fun = mean, geom = "point", size = 0.5, colour = "grey20") +
  #stat_summary(fun.data = mean_se, geom = "errorbar", width = 0.15, colour = "grey20") +
  labs(
    #x = "Sample",
    #y = "% aneuploid cells/embryo"
  ) +
  settheme + # Your custom lab theme
  theme(
    axis.text.x = element_text(angle = 45, hjust = 1),
    legend.position = "none"
  )+scale_fill_manual(values=color_celltype2)+
  scale_color_manual(values=color_celltype2)
# Save and Display
  ggsave(filename = sprintf("%s/D_%s_boxplot.pdf", outdir, title),
         plot = p, width = w, height = h)
p
# Out:
# plot without title

# %%
unique(plot_data_long$Condition)
# Out:
# [1] "Control"   "Reversine" "Mosaic"

# %%
plot_genes =  c("CDH1")

#reformat
plot_data_long <- combined_df %>%
  pivot_longer(
    cols = any_of(plot_genes), # Select the gene columns
    names_to = "gene", 
    values_to = "expression"
  )

plot_data_long_sub = plot_data_long %>% filter(celltype_coarse == "unspecified")%>% filter(sample %in% c('T3_mix_good','T3_mix_bad'))

#plot
title = "CDH1_unspecified"

w <- 1.5
h <- 2
options(repr.plot.width=w, repr.plot.height=h)

# 2. Create the Plot
p <- ggplot(plot_data_long_sub, aes(x = sample, y = expression, fill = celltype_coarse, color = celltype_coarse))+
   geom_boxplot(outlier.shape = NA, alpha = 0.5, width = 0.6) +
  
  # Add the jittered dots
  geom_jitter(width = 0.2, size = 0.1, alpha = 0.1) +
  
  # Facet by gene
  facet_wrap(~gene, scales = "free_y", nrow = 1) +
  
  # Labels and Theme
  labs(
    title = title,
    x = "",
   # y = "Log-Normalized Expression"
  ) +
  # mean ± SE
  stat_summary(fun = mean, geom = "point", size = 0.5, colour = "grey20") +
  stat_summary(fun.data = mean_se, geom = "errorbar", width = 0.15, colour = "grey20") +
  labs(
    #x = "Sample",
    #y = "% aneuploid cells/embryo"
  ) +
  settheme + # Your custom lab theme
  theme(
    axis.text.x = element_text(angle = 45, hjust = 1),
    legend.position = "none"
  )+scale_fill_manual(values=color_celltype)+
  scale_color_manual(values=color_celltype)
# Save and Display
  ggsave(filename = sprintf("%s/D_%s_boxplot.pdf", outdir, title),
         plot = p, width = w, height = h)
p
# Out:
# plot without title

# %%
plot_genes <- c("p53")

plot_data_long <- combined_df %>%
  pivot_longer(
    cols = any_of(plot_genes),
    names_to = "gene",
    values_to = "expression"
  )

plot_data_long_sub <- plot_data_long %>%
  filter(
    timepoint == "day1"
   # ploidy == "diploid"
  )

title <- "p53_unspecified"

w <- 3
h <- 2
options(repr.plot.width = w, repr.plot.height = h)

p <- ggplot(plot_data_long_sub, aes(x = ploidy , y = expression)) +
  # points with jitter+dodge (no width/height here)
  geom_jitter(aes(color = Condition),
    size = 0.3, alpha = 0.6,
    position = position_jitterdodge(jitter.width = 0.2, dodge.width = 0.6),
    na.rm = TRUE
  ) +
  geom_boxplot(
    aes(fill = Condition),
    width = 0.5, alpha = 0.25, outlier.shape = NA,
    position = position_dodge(width = 0.6)
  ) +
  labs(x = "", y = "p53 intensity", title = title) +
  #facet_wrap(~state)+
  settheme +
  #scale_y_continuous(limits = c(0, NA), expand = c(0, 0)) +
  #coord_flip() 
  #scale_color_manual(values = col_GFP) +
  #scale_fill_manual(values = palette, guide = "none") +
  theme( axis.text.x = element_text(angle = 45, hjust = 1), legend.position = "none")

ggsave(file.path(out_dir, sprintf("%s.pdf", title)), plot = p, width = w, height = h)
p
# Out:
# plot without title

# %% [markdown]
# ## D_Violin

# %%
plot_genes =  c("CDH1")

#reformat
plot_data_long <- combined_df %>%
  pivot_longer(
    cols = any_of(plot_genes), # Select the gene columns
    names_to = "gene", 
    values_to = "expression"
  )

#plot
title = "QC_celltype"

w <- 2
h <- 2
options(repr.plot.width=w, repr.plot.height=h)

# 2. Create the Plot
p <- ggplot(plot_data_long, aes(x = celltype_coarse, y = expression, fill = celltype_coarse, color = celltype_coarse))+
  # violin per sample within each ploidy facet
  geom_violin(
    alpha = 0.5,
    linewidth = 0.2,
    trim = TRUE,
      color = "grey"
  )+
  
  # Add the jittered dots
 # geom_jitter(width = 0.2, size = 0.1, alpha = 0.1) +
  
  # Facet by gene
  facet_wrap(~gene, scales = "free_y", nrow = 1) +
  
  # Labels and Theme
  labs(
    title = title,
    x = "",
   # y = "Log-Normalized Expression"
  ) +
  # mean ± SE
  stat_summary(fun = mean, geom = "point", size = 0.5, colour = "grey20") +
  stat_summary(fun.data = mean_se, geom = "errorbar", width = 0.15, colour = "grey20") +
  labs(
    #x = "Sample",
    #y = "% aneuploid cells/embryo"
  ) +
  settheme + # Your custom lab theme
  theme(
    axis.text.x = element_text(angle = 45, hjust = 1),
    legend.position = "none"
  )+scale_fill_manual(values=color_celltype)+
  scale_color_manual(values=color_celltype)
# Save and Display
  ggsave(filename = sprintf("%s/D_%s_violin.pdf", outdir, title),
         plot = p, width = w, height = h)
p
# Out:
# Warning message:
# “No shared levels found between `names(values)` of the manual scale and the
# data's colour values.”
# Warning message:
# “No shared levels found between `names(values)` of the manual scale and the
# data's colour values.”
# plot without title

# %%
plot_genes =  c("CDH1")

#reformat
plot_data_long <- combined_df %>%
  pivot_longer(
    cols = any_of(plot_genes), # Select the gene columns
    names_to = "gene", 
    values_to = "expression"
  )

plot_data_long_sub = plot_data_long %>% filter(celltype_coarse == "unspecified")%>% filter(sample %in% c('T3_mix_good','T3_mix_bad'))


#plot
title = "violin_CDH1_unspecified"

w <- 1.5
h <- 2
options(repr.plot.width=w, repr.plot.height=h)

# 2. Create the Plot
p <- ggplot(plot_data_long_sub, aes(x = sample, y = expression, fill = celltype_coarse, color = celltype_coarse))+
  # violin per sample within each ploidy facet
  geom_violin(
    alpha = 0.5,
    linewidth = 0.2,
    trim = TRUE,
      color = "grey"
  )+
  
  # Add the jittered dots
 # geom_jitter(width = 0.2, size = 0.1, alpha = 0.1) +
  
  # Facet by gene
  facet_wrap(~gene, scales = "free_y", nrow = 1) +
  
  # Labels and Theme
  labs(
    title = title,
    x = "",
   # y = "Log-Normalized Expression"
  ) +
  # mean ± SE
  stat_summary(fun = mean, geom = "point", size = 0.5, colour = "grey20") +
  stat_summary(fun.data = mean_se, geom = "errorbar", width = 0.15, colour = "grey20") +
  labs(
    #x = "Sample",
    #y = "% aneuploid cells/embryo"
  ) +
  settheme + # Your custom lab theme
  theme(
    axis.text.x = element_text(angle = 45, hjust = 1),
    legend.position = "none"
  )+scale_fill_manual(values=color_celltype)+
  scale_color_manual(values=color_celltype)
# Save and Display
  ggsave(filename = sprintf("%s/D_%s_violin.pdf", outdir, title),
         plot = p, width = w, height = h)
p
# Out:
# Warning message:
# “No shared levels found between `names(values)` of the manual scale and the
# data's colour values.”
# Warning message:
# “No shared levels found between `names(values)` of the manual scale and the
# data's colour values.”
# plot without title

# %% [markdown]
# ## E_Ratio

# %%
title   <- "celltype"

w <- 4; h <- 2
options(repr.plot.width=w, repr.plot.height=h)

bar_ratio <- ggplot(
    combined_df %>% subset(timepoint == "day6")%>%  subset(State== "Blastoid"), 
    aes(x = sample, fill = celltype_coarse)) +
    geom_bar(position='fill') +
    labs(
      x    = "Structure",
      y    = "Ratio",
      title = title 
    ) + coord_flip()+
    settheme +
    theme(
      #axis.text.x = element_text(angle = 45, hjust = 1)
    ) + scale_fill_manual(values=color_celltype)

ggsave(file.path(outdir, sprintf("E_%s.pdf", title)), plot = bar_ratio , width = w, height = h)
bar_ratio
# Out:
# Warning message:
# “No shared levels found between `names(values)` of the manual scale and the
# data's fill values.”
# Warning message:
# “No shared levels found between `names(values)` of the manual scale and the
# data's fill values.”
# plot without title

# %%
head(combined_df$State)
# Out:
# [1] "Naïve" "Naïve" "Naïve" "Naïve" "Naïve" "Naïve"

# %%
mlm_PROGENy_var
# Out:
#  [1] "Androgen" "EGFR"     "Estrogen" "Hypoxia"  "JAK-STAT" "MAPK"
#  [7] "NFkB"     "PI3K"     "TGFb"     "TNFa"     "Trail"    "VEGF"
# [13] "WNT"      "p53"
